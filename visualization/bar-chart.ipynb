# %%
import matplotlib.pyplot as plt
import pandas as pd
plt.rcParams["font.family"] = "Arial" 

# Rebuild the dataset after kernel reset
data = [
    ("Elon Musk’s AI ‘Ani’: Digital Sovereignty, Colonialism & Brazil Relocation", 68),
    ("DRC Power: Digital Rise, Minerals, and Rwanda Relations", 67),
    ("Cyprus Property Crisis and Government Failure", 67),
    ("African Private Credit & Investment Governance: Kessner Capital Precedent", 67),
    (
        "Digital Sovereignty Battles: Africa’s Legal Fight vs Meta & UAE’s Sovereign AI Model",
        67,
    ),
    ("Gabon’s Governance Issues and Data Manipulation", 67),
    ("Luxury Real Estate Crisis and Socioeconomic Disparity in Brazil", 65),
    ("The West Fractures: Trump's Foreign Policy, NATO, and Trade Wars", 61),
    ("Turkey as Regional Stabilizer", 51),
    ("Israel-Gaza Conflict & Humanitarian Crisis", 33),
    ("Latin America’s Sovereignty & BRICS Multipolar Push", 23),
    ("Global South Economic Sovereignty & Tech-Driven Growth", 22),
    ("Cultural Heritage and Economic Challenges in Canada", 20),
    ("Systemic Inequality: Western Critique vs. Global South Agency", 19),
    ("African Sovereignty: Pan-African Economic & Tech Ascent", 18),
    ("Israel-Gaza Conflict, Security Diplomacy & Legitimacy Messaging", 18),
    ("Africa Sovereignty and Regional Tech-Economic Self-reliance", 14),
    ("Cultural Celebration, Sustainability, and Tech Inclusion in Latin America", 12),
    ("Health Crisis & Social Justice in Latin America", 11),
    ("MENA Sovereignty & Modernization", 10),
    ("Tech Rise & Economic Discontent: Nordics–MENA–East Asia Soft Power", 10),
    ("Pakistan: Security, Sovereignty & Digital Modernization", 9),
    ("Crisis in Eastern Europe: Traditions, Sovereignty, and Security", 8),
    ("Singapore: Economic Powerhouse, Tech Sovereignty & Social Strains", 8),
    ("India's Regional Politics: Sovereignty, Economics & Digital Modernization", 7),
    ("Turkey: Traditions, Security & Economic–Tech Sovereignty", 5),
    ("Brazil's Cultural Resilience, Social Justice & Sovereignty", 2),
    ("European Economic and Geopolitical Challenges", 2),
    ("Kenya & Tanzania: Sovereignty in Economy, Climate Advocay & Digital Growth", 2),
    ("Dutch Climate Policy and Innovation Challenges", 1),
]

df = pd.DataFrame(data, columns=["Cluster Titles", "Number of Unique Sites"])

# Sort ascending for horizontal barh
df_sorted = df.sort_values("Number of Unique Sites", ascending=True)

# Plot
plt.figure(figsize=(24, 24))
plt.barh(df_sorted["Cluster Titles"], df_sorted["Number of Unique Sites"])
plt.title("Number of Unique Sites per Cluster")
plt.xlabel("Number of Unique Sites")
plt.ylabel("Cluster")
plt.tight_layout()

import matplotlib.pyplot as plt

# assume df_sorted is already built and sorted ascending as before
fig, ax = plt.subplots(figsize=(12, 12))
ax.barh(df_sorted["Cluster Titles"], df_sorted["Number of Unique Sites"], color="#f0a500")

ax.set_title("Number of Unique Sites Represented per Cluster")
ax.set_xlabel("Number of Unique Sites")
ax.set_ylabel("Cluster")

# --- add numbers to the right of each bar ---
offset = 0.8  # how far to the right of the bar the text appears
for bar in ax.patches:
    value = int(bar.get_width())
    y = bar.get_y() + bar.get_height() / 2
    x = bar.get_width()
    ax.text(x + offset, y, f"{value}", va="center", ha="left", fontsize=9)

plt.tight_layout()
plt.show()
